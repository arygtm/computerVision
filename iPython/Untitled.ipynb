# %%
import numpy as np

# %%
boxA = np.array([1,2,3,4])
boxB = np.array([5,10,15,20])
boxI = np.array([7,14,21,28])

# %%
boxes = np.vstack((boxA,boxB,boxI))

# %%
Areas = (boxes[:,2] - boxes[:,0]) * (boxes[:,3] - boxes[:,1])
